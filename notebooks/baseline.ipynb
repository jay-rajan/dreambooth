# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipeline.to("cuda")
pipeline("An image of a squirrel in Picasso style").images[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 from diffusers import DiffusionPipeline
#       2 import torch
# ----> 4 pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
#       5 pipeline.to("cuda")
#       6 pipeline("An image of a squirrel in Picasso style").images[0]
#
# File ~/micromamba/envs/diffusers/lib/python3.10/site-packages/diffusers/pipelines/pipeline_utils.py:939, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     936 # 1. Download the checkpoints and configs
#     937 # use snapshot download here to get it working from from_pretrained
#     938 if not os.path.isdir(pretrained_model_name_or_path):
# --> 939     cached_folder = cls.download(
#     940         pretrained_model_name_or_path,
#     941         cache_dir=cache_dir,
#     942         resume_download=resume_download,
#     943         force_download=force_download,
#     944         proxies=proxies,
#     945         local_files_only=local_files_only,
#     946         use_auth_token=use_auth_token,
#     947         revision=revision,
#     948         from_flax=from_flax,
#     949         use_safetensors=use_safetensors,
#     950         use_onnx=use_onnx,
#     951         custom_pipeline=custom_pipeline,
#     952         custom_revision=custom_revision,
#     953         variant=variant,
#     954         load_connected_pipeline=load_connected_pipeline,
#     955         **kwargs,
#     956     )
#     957 else:
#     958     cached_folder = pretrained_model_name_or_path
#
# File ~/micromamba/envs/diffusers/lib/python3.10/site-packages/diffusers/pipelines/pipeline_utils.py:1541, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1536 elif use_safetensors and is_safetensors_compatible(
#    1537     model_filenames, variant=variant, passed_components=passed_components
#    1538 ):
#    1539     ignore_patterns = ["*.bin", "*.msgpack"]
# -> 1541     use_onnx = use_onnx if use_onnx is not None else pipeline_class._is_onnx
#    1542     if not use_onnx:
#    1543         ignore_patterns += ["*.onnx", "*.pb"]
#
# File ~/micromamba/envs/diffusers/lib/python3.10/site-packages/diffusers/utils/import_utils.py:533, in DummyObject.__getattr__(cls, key)
#     531 if key.startswith("_") and key not in ["_load_connected_pipes", "_is_onnx"]:
#     532     return super().__getattr__(cls, key)
# --> 533 requires_backends(cls, cls._backends)
#
# File ~/micromamba/envs/diffusers/lib/python3.10/site-packages/diffusers/utils/import_utils.py:501, in requires_backends(obj, backends)
#     499 failed = [msg.format(name) for available, msg in checks if not available()]
#     500 if failed:
# --> 501     raise ImportError("".join(failed))
#     503 if name in [
#     504     "VersatileDiffusionTextToImagePipeline",
#     505     "VersatileDiffusionPipeline",
#    (...)
#     508     "UnCLIPPipeline",
#     509 ] and is_transformers_version("<", "4.25.0"):
#     510     raise ImportError(
#     511         f"You need to install `transformers>=4.25` in order to use {name}: \n```\n pip install"
#     512         " --upgrade transformers \n```"
#     513     )
#
# ImportError:
# StableDiffusionPipeline requires the transformers library but it was not found in your environment. You can install it with pip: `pip
# install transformers`
